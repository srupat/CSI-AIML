# %% [markdown]
# ## Installing all packages

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# Reading from the csv file

# %%
matches_df = pd.read_csv('each_match_records.csv')
#type(matches_df)
matches_df
# Out:
#     season        date  match_number  match_type
# 0     2023  31-03-2023             1       Group  \
# 1     2023  01-04-2023             2       Group
# 2     2023  01-04-2023             3       Group
# 3     2023  02-04-2023             4       Group
# 4     2023  02-04-2023             5       Group
# ..     ...         ...           ...         ...
# 69    2023  21-05-2023            70       Group
# 70    2023  23-05-2023            71   Qualifier
# 71    2023  24-05-2023            72  Eliminator
# 72    2023  26-05-2023            73   Qualifier
# 73    2023  29-05-2023            74       Final
#
#                                                 venue    location
# 0                               Narendra Modi Stadium   Ahmedabad  \
# 1        Punjab Cricket Association IS Bindra Stadium  Chandigarh
# 2   Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...     Lucknow
# 3                  Rajiv Gandhi International Stadium   Hyderabad
# ...

# %% [markdown]
# Primary Objectives
# - No of matches won by fielding first and batting first
# - Does winning the toss imply winning the match?
# - Is probability of winning on home pitch greater as compared to away pitches?
# - Most man of the match titles(can also find out whether bowlers are awarded man of the match awards or batters are)
# - Which venue supports winning as well as frequency of the venues used

# %%
columns_to_drop = ['winner_runs','winner_wickets']
matches_df = matches_df.drop(columns=columns_to_drop)
matches_df
# Out:
#           date  match_number  match_type
# 0   31-03-2023             1       Group  \
# 1   01-04-2023             2       Group
# 2   01-04-2023             3       Group
# 3   02-04-2023             4       Group
# 4   02-04-2023             5       Group
# ..         ...           ...         ...
# 69  21-05-2023            70       Group
# 70  23-05-2023            71   Qualifier
# 71  24-05-2023            72  Eliminator
# 72  26-05-2023            73   Qualifier
# 73  29-05-2023            74       Final
#
#                                                 venue    location
# 0                               Narendra Modi Stadium   Ahmedabad  \
# 1        Punjab Cricket Association IS Bindra Stadium  Chandigarh
# 2   Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...     Lucknow
# 3                  Rajiv Gandhi International Stadium   Hyderabad
# 4                               M Chinnaswamy Stadium   Bengaluru
# ..                                                ...         ...
# ...
